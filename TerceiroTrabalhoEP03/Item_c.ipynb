# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Grafico do item a

# %%
from Item_a import main as plot_a
plot_a()

# %% [markdown]
# # Grafico do item b

# %%
from Item_b import main as plot_b
plot_b()

# %% [markdown]
# ## Log-scaling

# %%
plot_b(log_scaling=True)

# %% [markdown]
# # Grafico do item c

# %%
plot_b(lmbd=700e-9)

# %% [markdown]
# ## Log-scaling

# %%
plot_b(log_scaling=True, lmbd=700e-9)

# %% [markdown]
# # Discussao

# %% [markdown]
# ## Diferencas

# %% [markdown]
# 1. Comparando pela escala de cores hot, a figura de difração da luz
# violeta tem as maiores intensidades mais concentradas perto do centro do
# plano focal, em relacao a luz vermelha, que se mostra mais delocalizada
# do centro.
#
# 2. Os graficos em escala logaritmica evidenciam os padroes de difracao,
# cujas figuras de maximos e minimos formam circumferencias de diametros
# menores para o menor comprimento de onda (violeta) e maiores para o
# maior comprimento (vermelha).

# %% [markdown]
# ## Similaridades

# %% [markdown]
# 1. Em relacao a escala hot, observa-se que, para ambos comprimentos de
# onda, a intensidade luminosa na proximidade do centro da figura eh muito
# maior em relacao a regiao mais periferica.
#
# 2. Aplicando escala logaritmica, fica evidente que a figura de difracao
# de ambos comprimentos de onda apresentam as mesmas formas circulares
# concentricas de maximos e minimos.
