# %% [markdown]
# por Felipe Miyazato

# %%
from Item_a import do_plot
from Item_b import six_lwr_lvls

# %% [markdown]
# # Item a

# %%
do_plot()

# %% [markdown]
# Estimativas visuais:
#  - E_1: 0.3 eV,
#  - E_2: 1.3 eV,
#  - E_3: 2.9 eV,
#  - E_4: 5.1 eV,
#  - E_5: 7.9 eV,
#  - E_6: 11.2 eV

# %% [markdown]
# # Item c

# %%
do_plot(omega=1e-9/2)

# %% [markdown]
# Estimativas visuais:
#  - E_1: 1.1 eV,
#  - E_2: 4.3 eV,
#  - E_3: 9.5 eV,
#  - E_4: 16.2 eV

# %%
print('Seis primeiros níveis de energia:')
six_lwr_lvls(w=1e-9/2)
# Out:
# Seis primeiros níveis de energia:
# Sem interseccoes pares no intervalo [13.53706229385217, 19.999999],
# dada precisao 0.001
# {'E_1': 1.087326987225919,
#  'E_2': 4.3092836903104725,
#  'E_3': 9.517144241523345,
#  'E_4': 16.237184471194816}

# %% [markdown]
# O que muda:
#  - diminui o numero de interseccoes pela metade,
#  - energias de mesmo indice com valor maior
#
# Acontece que a forma da curva tangente dilata e parte de seus periodos escapa do dominio das funcoes par e impar, levando estas solucoes para dominio complexo. Enquanto as energias que nao escapam, a dilatacao afasta seus valores de zero.

# %% [markdown]
# # Item d

# %%
do_plot(V=40)

# %% [markdown]
# Estimativas visuais:
#  - E_1: 0.3 eV,
#  - E_2: 1 eV,
#  - E_3: 3 eV,
#  - E_4: 5 eV,
#  - E_5: 8 eV,
#  - E_6: 11 eV

# %%
print('Seis primeiros níveis de energia:')
six_lwr_lvls(V=40)
# Out:
# Seis primeiros níveis de energia:
# {'E_1': 0.3337988317087571,
#  'E_2': 1.3333627104757275,
#  'E_3': 2.9975858277646283,
#  'E_4': 5.32280047099846,
#  'E_5': 8.302392453022021,
#  'E_6': 11.928195365631147}

# %% [markdown]
# O que muda:
#  - aumenta o numero de interseccoes de 3,
#  - energias de mesmo indice com valor maior
#
# Acontece que a forma das curvas par e impar dilatam, trazendo solucoes do dominio complexo para o real. Enquanto as energias que ja eram de dominio Real tem seu valor aumentado em relacao a $V = 20$ eV.
